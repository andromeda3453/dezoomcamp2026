# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=ride_deserializer
)

# %%
from datetime import datetime

print(f"Listening to {topic_name}...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
    print(f"Received: PU={ride.PULocationID}, DO={ride.DOLocationID}, "
          f"distance={ride.trip_distance}, amount=${ride.total_amount:.2f}, "
          f"pickup={pickup_dt}")
    count += 1
    if count >= 10:
        print(f"\n... received {count} messages so far (stopping after 10 for demo)")
        break

consumer.close()
# Out:
# Listening to rides...
# Received: PU=158, DO=88, distance=3.3, amount=$44.00, pickup=2025-11-01 04:00:03
# Received: PU=88, DO=148, distance=1.5, amount=$19.55, pickup=2025-11-01 04:43:53
# Received: PU=148, DO=236, distance=4.7, amount=$47.65, pickup=2025-11-01 04:58:02
# Received: PU=87, DO=255, distance=5.61, amount=$38.85, pickup=2025-11-01 04:52:48
# Received: PU=231, DO=43, distance=3.9, amount=$46.55, pickup=2025-11-01 04:05:53
# Received: PU=141, DO=262, distance=1.14, amount=$14.90, pickup=2025-11-01 04:13:44
# Received: PU=238, DO=24, distance=0.6, amount=$9.12, pickup=2025-11-01 04:03:18
# Received: PU=236, DO=147, distance=4.3, amount=$29.20, pickup=2025-11-01 04:19:55
# Received: PU=231, DO=137, distance=3.0, amount=$32.75, pickup=2025-11-01 04:45:55
# Received: PU=237, DO=237, distance=0.69, amount=$11.50, pickup=2025-11-01 04:11:12
#
# ... received 10 messages so far (stopping after 10 for demo)
